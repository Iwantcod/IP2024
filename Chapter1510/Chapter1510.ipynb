# %% [markdown]
# <h1>Chapter 1.5.10 Feature Matching + Homography to find Objects</h1>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('view1.png',0) # queryImage
img2 = cv2.imread('view5.png',0) # trainImage

sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
# matches = bf.match(des1,des2)
matches = matcher.match(des1, des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# %%
# Draw first 10 matches.
# img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], flags=2)
img3 = cv2.drawMatches(img1, kp1, img2, kp2, matches[:30], None, \
                       flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)


plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1515239a0>, None)

# %%
img1 = cv2.imread('moter_part.png',0) # queryImage
img2 = cv2.imread('moter1.png',0) # trainImage

sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
# matches = bf.match(des1,des2)
matches = matcher.match(des1, des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# %%
# Draw first 10 matches.
# img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10], flags=2)
img3 = cv2.drawMatches(img1, kp1, img2, kp2, matches[:50], None, \
                       flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)



plt.figure(figsize=(24,8))
plt.subplot(1,2,1), plt.imshow(img3)
plt.xticks([]), plt.yticks([])

plt.show()
