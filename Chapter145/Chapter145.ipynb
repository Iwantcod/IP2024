# %% [markdown]
# <h1>Chapter 1.4.5 Morphological Transformations</h1>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# <p>1. Erosion</p>

# %%
# Erosion 연산(침식 연산)을 통해 깎아낸다.

img = cv2.imread('j.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((7,7),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(erosion),plt.title('Erosion')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>2. Dilation</p>

# %%
# Dilation 연산(팽창 연산)을 통해 범위를 늘린다.

img = cv2.imread('j.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((10,10),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dilation),plt.title('Dilation')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>3. Opening</p>

# %%
# Opening 연산(열기 연산): Erosion 후 Dilation
# 줄이고 늘리고

img = cv2.imread('./beforeOpening.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((10,10),np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(opening),plt.title('Opening')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>4. Closing</p>

# %%
# Closing 연산(닫기 연산): Dilation 후 Erosion
# 늘리고 줄이고

img = cv2.imread('./beforeClosing.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((10,10),np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(closing),plt.title('Closing')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>5. Morphological Gradient</p>

# %%
img = cv2.imread('j.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((10,10),np.uint8)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gradient),plt.title('Morphological Gradient')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>6. Top Hat</p>

# %%
# It is the difference between input image and Opening of the image. Below example is done for a 9x9 kernel

img = cv2.imread('j.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((20,20),np.uint8)
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(tophat),plt.title('Top Hat')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <p>7. Black Hat</p>

# %%
# It is the difference between the closing of the input image and input image.

img = cv2.imread('j.png', cv2.IMREAD_GRAYSCALE)
# 커널의 크기
kernel = np.ones((20,20),np.uint8)
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blackhat),plt.title('Black Hat')
plt.xticks([]), plt.yticks([])
plt.show()
